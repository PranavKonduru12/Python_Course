# %%
'hello'
# Out:
# 'hello'

# %%
"world"
# Out:
# 'world'

# %%
'this is also a string'
# Out:
# 'this is also a string'

# %%
"I'm also going on a run"
# Out:
# "I'm also going on a run"

# %% [markdown]
# Printing out a string

# %%
print("hello")#print function
# Out:
# hello

# %%
"hello world one"
"hello world two"
# Out:
# 'hello world two'

# %%
print("hello world one")
print("hello world two")
# Out:
# hello world one
# hello world two

# %% [markdown]
# Escape sequence

# %%
print('hello world')
# Out:
# hello world

# %%
print('hello \n world') #escape sequence
# Out:
# hello
#  world

# %%
print('hello \nworld')
# Out:
# hello
# world

# %%
print('hello \tworld')
# Out:
# hello 	world

# %% [markdown]
# Length function

# %%
len('hello')
# Out:
# 5

# %%
len('I am')
# Out:
# 4

# %% [markdown]
# ### Indexing and Slicing with Strings

# %%
mystring = "Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[0] #Grab single character from string
# Out:
# 'H'

# %%
mystring[8] #Indexing
# Out:
# 'r'

# %%
mystring[9]
# Out:
# 'l'

# %%
mystring[-3] #Reverse Indexing
# Out:
# 'r'

# %% [markdown]
# Slicing - grabbing subsection

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring = 'abcdefghijk'

# %%
mystring
# Out:
# 'abcdefghijk'

# %%
mystring[2:] #goes all the way to the end
# Out:
# 'cdefghijk'

# %%
mystring[:3] #everying up to a particular index d
# Out:
# 'abc'

# %% [markdown]
# Stop index is saying to go up to but not include

# %%
mystring[3:6] #grab def
# Out:
# 'def'

# %%
mystring[1:3]
# Out:
# 'bc'

# %%
mystring[7:9] #grab hi
# Out:
# 'hi'

# %% [markdown]
# Step Size

# %%
mystring[::]
# Out:
# 'abcdefghijk'

# %%
mystring[::2] #stepsize jumps of 2
# Out:
# 'acegik'

# %%
mystring[::3]
# Out:
# 'adgj'

# %%
mystring[2:7:2]
# Out:
# 'ceg'

# %%
mystring[::-1] #Can be used to reverse string
# Out:
# 'kjihgfedcba'

# %% [markdown]
# ## Immutability

# %% [markdown]
# Cannot mutate or cannot change

# %%
name = "Sam"

# %% [markdown]
# name[0] = 'P' does not work

# %%
last_letters = name[1:] #grab a and m

# %%
last_letters
# Out:
# 'am'

# %%
'P' + last_letters #String concattenation
# Out:
# 'Pam'

# %%
x = 'Hello World'

# %%
x = x + " it is beautiful outisde!" #add the space in the front

# %%
x
# Out:
# 'Hello World it is beautiful outisde!'

# %%
x
# Out:
# 'Hello World it is beautiful outisde!'

# %%
x
# Out:
# 'Hello World it is beautiful outisde!'

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
2 + 3
# Out:
# 5

# %%
'2' + '3' #dynamic typing
# Out:
# '23'

# %%
x = 'Hello World'

# %%
x.upper() #method is not in place
# Out:
# 'HELLO WORLD'

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.split() #create a list of a string
# Out:
# ['Hello', 'World']

# %%
x = 'Hi this is a string'

# %%
x.split()
# Out:
# ['Hi', 'this', 'is', 'a', 'string']

# %%
x.split('i')
# Out:
# ['H', ' th', 's ', 's a str', 'ng']

# %%
True #Needs to be capitalized
# Out:
# True

# %%
False
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
1 > 2
# Out:
# False

# %%
1 == 1 #Comparison Operators
# Out:
# True

# %%
b = None

# %%
b #None keyword can be used as placeholder

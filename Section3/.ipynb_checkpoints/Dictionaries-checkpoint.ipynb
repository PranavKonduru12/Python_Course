# %%
my_dict = {'key1':'value1','key2':'value2'}

# %%
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
prices_lookup = {'apple':2.99,'oranges':1.99,'milk':5.80}

# %%
prices_lookup['apple'] #Usecase
# Out:
# 2.99

# %% [markdown]
# Flexible with the data types they can hold, including lists

# %%
d = {'k1':123,'k2':[0,1,2],'k3':{'insideKey':100}}

# %%
d['k2']
# Out:
# [0, 1, 2]

# %%
d['k3']['insideKey']
# Out:
# 100

# %%
d = {'key1':['a','b','c']}

# %%
mylist = d['key1']

# %%
mylist
# Out:
# ['a', 'b', 'c']

# %%
letter = mylist[2]

# %%
letter
# Out:
# 'c'

# %%
letter.upper()
# Out:
# 'C'

# %% [markdown]
# Could do all of this in one step

# %%
d['key1'][2].upper()
# Out:
# 'C'

# %%
d = {'k1':100,'k2':200}

# %%
d
# Out:
# {'k1': 100, 'k2': 200}

# %%
d['k3'] = 300 #Add new key pair

# %%
d
# Out:
# {'k1': 100, 'k2': 200, 'k3': 300}

# %%
d['k1'] = 'NEW VALUE' #Overright existing key pair

# %%
d
# Out:
# {'k1': 'NEW VALUE', 'k2': 200, 'k3': 300}

# %%
d = {'k1': 100, 'k2': 200, 'k3': 300}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d.values()
# Out:
# dict_values([100, 200, 300])

# %%
d.items() #pairings
# Out:
# dict_items([('k1', 100), ('k2', 200), ('k3', 300)])

# %%
my_list = [1,2,3] #List of integers

# %%
my_list = ['STRING',100,23.2]#List of mixed object types

# %%
len(my_list)#check length of list
# Out:
# 3

# %% [markdown]
# List is ordered sequence of elements

# %%
mylist = ['one','two','three']

# %%
mylist[0]
# Out:
# 'one'

# %%
mylist[1:]#Slicing
# Out:
# ['two', 'three']

# %%
another_list = ['four','five']#Concatenation

# %%
new_list = mylist + another_list

# %%
new_list#Needs to be assinged to be saved
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list#list can be manipulated
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list[0] = 'ONE ALL CAPS'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
new_list.append('six')#Add element to end of list

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
new_list.append('seven')

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six', 'seven']

# %%
new_list.pop()#Removing items from list
# Out:
# 'seven'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
popped_item = new_list.pop()

# %%
popped_item
# Out:
# 'six'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
new_list.pop(0)
# Out:
# 'ONE ALL CAPS'

# %%
new_list = ['a','e','x','b','c']
num_list = [4,1,8,3]

# %%
new_list.sort()#Sort method

# %%
new_list #Sorted in alphabetical order
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %% [markdown]
# None type = default return value

# %%
new_list.sort()
my_sorted_list = new_list

# %%
my_sorted_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list
# Out:
# [4, 1, 8, 3]

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 3, 4, 8]

# %%
num_list.reverse() #Reverse

# %%
num_list
# Out:
# [8, 4, 3, 1]

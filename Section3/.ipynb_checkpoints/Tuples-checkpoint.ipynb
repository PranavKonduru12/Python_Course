# %%
t = (1,2,3) #Tuples

# %%
mylist = [1,2,3]

# %%
type(mylist)
# Out:
# list

# %%
type(t)
# Out:
# tuple

# %%
t
# Out:
# (1, 2, 3)

# %%
t = ('one',2)

# %%
t[0]
# Out:
# 'one'

# %%
t[-1]
# Out:
# 2

# %%
t = ('a','a','b') #Index method

# %%
t.count('a') #How many times a occurs in that tuple
# Out:
# 2

# %%
t.index('a') #Returns that the index location appears first
# Out:
# 0

# %%
t.index('b')
# Out:
# 2

# %% [markdown]
# Immutability differentiates tuples from lists

# %%
mylist[0] = 'NEW' #Immutability

# %%
mylist
# Out:
# ['NEW', 2, 3]

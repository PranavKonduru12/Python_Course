# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10 #reassigning

# %%
a
# Out:
# 10

# %%
a + a
# Out:
# 20

# %%
a = a + a#reassignment with reference to object

# %%
a
# Out:
# 40

# %%
type(a) #built-in keyword
# Out:
# int

# %%
a = 30.1

# %%
type(a)
# Out:
# float

# %%
my_income = 100

tax_rate = 0.1 #10% tax rate

my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 10.0

# %% [markdown]
# #### Using Python as Calculator

# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %% [markdown]
# #### "Mod" Operator

# %% [markdown]
# Returns back the remainder after the division

# %%
7 / 4
# Out:
# 1.75

# %%
7 % 4 #remainder
# Out:
# 3

# %%
50 % 5
# Out:
# 0

# %%
23 % 2 #we have an odd number
# Out:
# 1

# %%
20 % 2
# Out:
# 0

# %% [markdown]
# Powers

# %%
2 **3
# Out:
# 8

# %% [raw]
# Order of Operations

# %%
2 + 10 * 10 + 3 #BODMAS
# Out:
# 105

# %%
(2 + 10) * (10 + 3)
# Out:
# 156
